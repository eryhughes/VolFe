# %%
# load data
data = pd.read_csv("example_marianas.csv")
raw_data = np.array(data)
data = pd.read_csv("saturation pressure/saturation_pressures1.csv")
pvsat1_data = np.array(data)
data = pd.read_csv("saturation pressure/saturation_pressures2.csv")
pvsat2_data = np.array(data)
data = pd.read_csv("random comp generator/random_compositions.csv")
random_data = np.array(data)
data = pd.read_csv("calculate isobars/results_isobars.csv")
isobar_data = np.array(data)
data = pd.read_csv("fO2 range based on sulfur content/fO2_range_from_S1.csv")
SfO21_data = np.array(data)
data = pd.read_csv("fO2 range based on sulfur content/fO2_range_from_S2.csv")
SfO22_data = np.array(data)
data = pd.read_csv("gassing over pressure/results_gassing_chemistry.csv")
degas_data = np.array(data)
data = pd.read_csv("pure CO2 and H2O/results_pure_solubility.csv")
pure_data = np.array(data)
data = pd.read_csv("fugacity coefficients/fugacity_coefficients_outputs.csv")
f_data = np.array(data)

# %%
### volatile concentrations and TAS plot

def plot_composition(data,CO2_H2O="yes",S_Fe3T="yes",tas="yes")

    if CO2_H2O == "yes" and S_Fe3FeT == "yes" and tas == "yes":
        no_col = 3
        fig_width = 1000
            else:

    fig = make_subplots(rows=1, cols=3,
                   shared_yaxes = False, shared_xaxes = False,
                   vertical_spacing=0.08, horizontal_spacing=0.07)
lw = 3
syms = 10
lc = "steelblue"

data = raw_data

# H2O-CO2
r = 1
c = 1
fig.add_trace(go.Scatter(mode = "lines", x=isobar_data[:,1], y=isobar_data[:,2], line_color = "darkgrey", line_width = 1, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data[:,16], y=data[:,17],
                         marker=dict(symbol=data[:,26], color=data[:,25], line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,6.1], dtick = 1, title = "H<sub>2</sub>O-eq (wt%)", row = r, col = c)
fig.update_yaxes(range = [0,1700], dtick = 500, title = "CO<sub>2</sub>-eq (ppm)", row = r, col = c)
fig.add_annotation(x=5.8, y=1600,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
fig.add_annotation(x=0.4, y=540,text="1kb",showarrow=False,font=dict(color="darkgrey",size=15),textangle=0,  row = r, col = c)
fig.add_annotation(x=0.4, y=1070,text="2kb",showarrow=False,font=dict(color="darkgrey",size=15),textangle=0,  row = r, col = c)
fig.add_annotation(x=0.4, y=1540,text="3kb",showarrow=False,font=dict(color="darkgrey",size=15),textangle=0,  row = r, col = c)

# S-Fe3+/FeT
r = 1
c = 2
fig.add_trace(go.Scatter(mode = "markers", x=data[:,18], y=data[:,20],
                         marker=dict(symbol=data[:,26], color=data[:,25], line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,1800], dtick = 500, title = "S<sub>T</sub> (ppm)", row = r, col = c)
fig.update_yaxes(range = [0,0.3], dtick = 0.1, title = "Fe<sup>3+</sup>/Fe<sub>T</sub>", row = r, col = c)
fig.add_annotation(x=1700, y=0.02,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# TAS
r = 1
c = 3
fig.add_trace(go.Scatter(mode = "lines", x=[41,41,45,45,52,52,57,57], y=[7,-1,-1,5,5,-1,-1,5.9], line_color = "darkgrey", line_width = 1, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=[41,45], y=[3,3], line_color = "darkgrey", line_width = 1, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data[:,3], y=data[:,13]+data[:,14],
                         marker=dict(symbol=data[:,26], color=data[:,25], line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.update_xaxes(range = [40,60], dtick = 5, title = "SiO<sub>2</sub> (wt%)", row = r, col = c)
fig.update_yaxes(range = [0,5], dtick = 1, title = "Na<sub>2</sub>O+K<sub>2</sub>O (wt%)", row = r, col = c)
fig.add_annotation(x=59, y=0.3,text="c",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
fig.add_annotation(x=48.5, y=0.9,text="basalt",showarrow=False,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
fig.add_annotation(x=54.6, y=1.1,text="basaltic",showarrow=False,font=dict(color="black",size=15),textangle=0,  row = r, col = c)
fig.add_annotation(x=54.6, y=0.8,text="andesite",showarrow=False,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

fig.update_layout(height=400, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()
#fig.write_image("fig3.svg")
# Out:
# <div>
#
#
#             <div id="457848fd-4d45-4cfb-a055-9289e45ab0a9" class="plotly-graph-div" style="height:400px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("457848fd-4d45-4cfb-a055-9289e45ab0a9")) {
#                     Plotly.newPlot(
#                         '457848fd-4d45-4cfb-a055-9289e45ab0a9',
# ...

# %%
### saturation pressure and fO2 from S content

fig = make_subplots(rows=1, cols=3,
                   shared_yaxes = True, shared_xaxes = False,
                   vertical_spacing=0.08, horizontal_spacing=0.05)
lw = 3
syms = 10
lc1 = "steelblue"
lc2 = "lightgrey"
lc3 = "firebrick"
lc4 = "white"

data1 = pvsat1_data
data2 = pvsat2_data
data3 = SfO21_data
data4 = SfO22_data
r = 1

# Pvsat vs. CO2
c = 1
fig.add_trace(go.Scatter(mode = "markers", x=data2[2:,16], y=data2[2:,1],
                         marker=dict(symbol="circle", color=lc2, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data1[2:,16], y=data1[2:,1],
                         marker=dict(symbol="circle", color=lc1, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,1700], dtick = 500, title = "CO<sub>2</sub>-eq (ppm)", row = r, col = c)
fig.update_yaxes(range = [4500,0], dtick = 500, title = "<i>P<sup>v</sup></i><sub>sat</sub> (bars)", row = r, col = c)
fig.add_annotation(x=1600, y=300,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# Pvsat vs. DFMQ
c = 2
fig.add_trace(go.Scatter(mode = "markers", x=data4[2:,8], y=data4[2:,5],
                         marker=dict(symbol="triangle-right", color=lc4, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data3[2:,8], y=data3[2:,5],
                         marker=dict(symbol="triangle-right", color=lc3, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data2[2:,4], y=data2[2:,1],
                         marker=dict(symbol="circle", color=lc2, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data1[2:,4], y=data1[2:,1],
                         marker=dict(symbol="circle", color=lc1, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.update_xaxes(range = [0,2], dtick = 0.5, title = "\u0394FMQ", row = r, col = c)
fig.add_annotation(x=0.1, y=300,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# Pvsat vs. dpvsat
c = 3
fig.add_trace(go.Scatter(mode = "markers", x=data2[2:,88], y=data2[2:,1],
                         marker=dict(symbol="circle", color=lc2, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.add_trace(go.Scatter(mode = "markers", x=data1[2:,88], y=data1[2:,1],
                         marker=dict(symbol="circle", color=lc1, line_color="black", size=syms, line_width=1)), row = r, col = c)
fig.update_xaxes(range = [-300,0], dtick = 100, title = "\u0394<i>P<sup>v</sup></i><sub>sat</sub> (bars)", row = r, col = c)
fig.add_annotation(x=-280, y=300,text="c",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)


fig.update_layout(height=400, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()
#fig.write_image("fig3.svg")
# Out:
# <div>
#
#
#             <div id="9e45fad4-d6f9-4223-ad8b-216cc322c1f6" class="plotly-graph-div" style="height:400px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e45fad4-d6f9-4223-ad8b-216cc322c1f6")) {
#                     Plotly.newPlot(
#                         '9e45fad4-d6f9-4223-ad8b-216cc322c1f6',
# ...

# %%
### saturation pressure

fig = make_subplots(rows=2, cols=3,
                   shared_yaxes = True, shared_xaxes = False,
                   vertical_spacing=0.08, horizontal_spacing=0.05)
lw = 3
syms = 10
lc1 = "steelblue"

data1 = degas_data
data2 = pure_data
r = 1

# P vs. CO2
c = 1
fig.add_trace(go.Scatter(mode = "lines", x=data2[:,2], y=data2[:,0], line_color = "darkgrey", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:,104], y=data1[2:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.update_xaxes(range = [0,1700], dtick = 500, title = "CO<sub>2</sub>-eq (ppm)", row = r, col = c)
fig.update_yaxes(range = [4000,0], dtick = 500, title = "<i>P</i> (bars)", row = r, col = c)
fig.add_annotation(x=1600, y=250,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# P vs. H2O
c = 2
fig.add_trace(go.Scatter(mode = "lines", x=data2[:,1], y=data2[:,0], line_color = "darkgrey", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:,105], y=data1[2:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.update_xaxes(range = [0,4.2], dtick = 1, title = "H<sub>2</sub>O-eq (wt%)", row = r, col = c)
fig.add_annotation(x=3.9, y=250,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# P vs. S
c = 3
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:,106], y=data1[2:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.update_xaxes(range = [0,1400], dtick =500, title = "S<sub>T</sub> (ppm)", row = r, col = c)
fig.add_annotation(x=1300, y=250,text="c",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

r = 2

# P vs. FMQ
c = 1
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:,35], y=data1[2:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.update_xaxes(range = [-0.5,1], dtick = 0.5, title = "\u0394FMQ", row = r, col = c)
fig.update_yaxes(range = [4000,0], dtick = 500, title = "<i>P</i> (bars)", row = r, col = c)
fig.add_annotation(x=0.9, y=250,text="d",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# P vs. S and Fe
c = 2
fig.add_trace(go.Scatter(mode = "lines", x=data1[3:,34], y=data1[3:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:,32], y=data1[2:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.update_xaxes(range = [0,0.4], dtick = 0.1, title = "Fe<sup>3+</sup>/Fe<sub>T</sub> or S<sup>6+</sup>/S<sub>T</sub>", row = r, col = c)
fig.add_annotation(x=0.38, y=250,text="e",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# P vs. CS
c = 3
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:,14], y=data1[2:,0], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.update_xaxes(range = [0,30], dtick = 5, title = "C/S<sup>vapor</sup> (mole fraction)", row = r, col = c)
fig.add_annotation(x=28, y=250,text="f",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)


fig.update_layout(height=700, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()
#fig.write_image("fig3.svg")
# Out:
# <div>
#
#
#             <div id="f710160c-1586-4d1f-bd17-b3392a3efc44" class="plotly-graph-div" style="height:700px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f710160c-1586-4d1f-bd17-b3392a3efc44")) {
#                     Plotly.newPlot(
#                         'f710160c-1586-4d1f-bd17-b3392a3efc44',
# ...

# %%
### saturation pressure

fig = make_subplots(rows=2, cols=2,
                   shared_yaxes = True, shared_xaxes = False,
                   vertical_spacing=0.08, horizontal_spacing=0.05)
lw = 2
syms = 10
lc1 = "steelblue"

data1 = f_data
r = 1

# vary T
c = 1
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,3], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,4], line_color = "firebrick", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,5], line_color = "steelblue", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,6], line_color = "firebrick", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,7], line_color = "black", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,8], line_color = "firebrick", line_width = lw, 
                         line_dash = "dot"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,9], line_color = "orange", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,10], line_color = "orange", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,11], line_color = "orange", line_width = lw, 
                         line_dash = "dot"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[2:8,2], y=data1[2:8,12], line_color = "steelblue", line_width = lw, 
                         line_dash = "dot"), row = r, col = c)
fig.update_xaxes(range = [800,1400], dtick = 100, title = "<i>T</i> (\u00B0C)", row = r, col = c)
fig.update_yaxes(range = [0,5], dtick = 1, title = "fugacity coefficient", row = r, col = c)
fig.add_annotation(x=820, y=4.7,text="a",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)

# vary P
c = 2
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,3], line_color = "steelblue", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,4], line_color = "firebrick", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,5], line_color = "steelblue", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,6], line_color = "firebrick", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,7], line_color = "black", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,8], line_color = "firebrick", line_width = lw, 
                         line_dash = "dot"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,9], line_color = "orange", line_width = lw, 
                         line_dash = "dash"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,10], line_color = "orange", line_width = lw, 
                         line_dash = "solid"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,11], line_color = "orange", line_width = lw, 
                         line_dash = "dot"), row = r, col = c)
fig.add_trace(go.Scatter(mode = "lines", x=data1[8:,1], y=data1[8:,12], line_color = "steelblue", line_width = lw, 
                         line_dash = "dot"), row = r, col = c)
fig.update_xaxes(range = [0,5000], dtick = 1000, title = "<i>P</i> (bars)", row = r, col = c)
fig.add_annotation(x=200, y=4.7,text="b",showarrow=False, bordercolor = "black", bgcolor="white",
                   width=15, height=15,font=dict(color="black",size=15),textangle=0,  row = r, col = c)




fig.update_layout(height=700, width=1000, plot_bgcolor='rgb(255,255,255)' , showlegend = False)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                 title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, 
                 ticks="inside", ticklen=5, title_standoff = 0, tickcolor="black",
                title_font=dict(size=15, family='Helvetica', color='black'), 
                 tickfont=dict(family='Helvetica', color='black', size=12))

fig.update_layout(font_family="Helvetica",font_color="black")

fig.show()
#fig.write_image("fig3.svg")
# Out:
# <div>
#
#
#             <div id="ba7bddc7-4207-4497-9cf5-f96473c0241e" class="plotly-graph-div" style="height:700px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ba7bddc7-4207-4497-9cf5-f96473c0241e")) {
#                     Plotly.newPlot(
#                         'ba7bddc7-4207-4497-9cf5-f96473c0241e',
# ...

# %%
data1[8:,1]
# Out:
# array(['1', '100', '200', '300', '400', '500', '600', '700', '800', '900',
#        '1000', '2000', '3000', '4000', '5000'], dtype=object)
