# %% [markdown]
# # Get values for tests
#
# This notebook runs the calculations in the tests files to get their values.
#
# ## Python set-up

# %%
import VolFe as vf
import pandas as pd

# %% [markdown]
# ## Test Pvsat functions
#
# ### Simple test of calc_pvsat function using FeOT and Fe3FeT using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Fe3FeT": 0.155,
    }  # mole or weight fraction (they're the same)

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (330.781731652385, 0.28960414241780263)

# %% [markdown]
# ### Simple test of calc_pvsat function using Fe2O3T and DFMQ using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "Fe2O3T": 9.47,  # Fe2O3T instead of FeOT
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "DFMQ": 0.0,
    }  # DFMQ instead of Fe3+/FeT

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "Fe3+/FeT"]
# Out:
# (324.46984008025794, 0.13813893016613535)

# %% [markdown]
# ### Simple test of calc_pvsat function using FeO and Fe2O3 using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeO": 8.03,  # FeO and Fe2O3 to contraint total Fe and fO2
        "Fe2O3": 2.57,  # ^
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (421.138400557486, 1.287568712477623)

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT and DNNO using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeOT": 9.47,
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "DNNO": 1.0,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "Fe3+/FeT"]
# Out:
# (477.3369430755751, 0.26725365489217384)

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT and S6+/ST using example 1a

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeOT": 9.47,
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "S6ST": 0.23,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (412.80473362888443, 1.0229078685870343)

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT, DNNO, and Fe3+/FeT

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,
        "SiO2": 56.98,
        "TiO2": 1.66,
        "Al2O3": 15.52,
        "FeOT": 9.47,
        "MnO": 0.24,
        "MgO": 2.96,
        "CaO": 6.49,
        "Na2O": 4.06,
        "K2O": 0.38,
        "P2O5": 0.22,
        "H2O": 1.88,
        "CO2ppm": 13.0,
        "STppm": 362.83,
        "Xppm": 0.0,
        "DNNO": 1.0,
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "Fe3+/FeT"]
# Out:
# C:\Users\erych\projects\VolFe\src\VolFe\melt_gas.py:2023: UserWarning: you entered more than one way to infer iron speciation, note that this calcualtion is only considering the entered Fe3+/FeT
#   w.warn(
# (330.781731652385, 0.155)

# %% [markdown]
# ### Simple test of calc_pvsat function using FeOT and Fe3FeT with user defined options using example 1c

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Fe3FeT": 0.155,
    }  # mole or weight fraction (they're the same)

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["carbon dioxide", "Basalt_Dixon97"],
        ["hydrogen sulfide", "BasalticAndesite_Hughes24"],
        ["y_S2", "ideal"],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (279.88640811865804, 0.2883015061880503)

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ar in basalt using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result1 = vf.calc_Pvsat(my_analysis)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (580.1382319929767, 0.29594295301335194)

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ar in rhyolite using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["species X solubility", "Ar_Rhyolite_Hughes25"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (376.0555328591023, 0.2907603795983995)

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ne in basalt using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["species X", "Ne"], ["species X solubility", "Ne_Basalt_Hughes25"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (463.21887716871447, 0.29297974431457785)

# %% [markdown]
# ### Simple test of calc_pvsat function including X as Ne in rhyolite using example 1d

# %%
my_analysis = {
        "Sample": "TN273-01D-01-01",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 56.98,  # wt%
        "TiO2": 1.66,  # wt%
        "Al2O3": 15.52,  # wt%
        "FeOT": 9.47,  # wt%
        "MnO": 0.24,  # wt%
        "MgO": 2.96,  # wt%
        "CaO": 6.49,  # wt%
        "Na2O": 4.06,  # wt%
        "K2O": 0.38,  # wt%
        "P2O5": 0.22,  # wt%
        "H2O": 1.88,  # wt%
        "CO2ppm": 13.0,  # ppm
        "STppm": 362.83,  # ppm
        "Xppm": 20.0,  # ppm *** 20 ppm "X" added**
        "Fe3FeT": 0.155,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["species X", "Ne"], ["species X solubility", "Ne_Rhyolite_Hughes25"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result1 = vf.calc_Pvsat(my_analysis, models=my_models)

result1.loc[0, "P_bar"], result1.loc[0, "fO2_DFMQ"]
# Out:
# (354.317755081519, 0.2902055195533597)

# %% [markdown]
# ## Test degassing functions
#
# ### Simple test of calc_gassing function using example 2a

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.,  # wt%
        "CO2ppm": 100.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  77%|███████▋  | 259.0/338 [00:25<00:07, 10.20it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 22
#       1 my_analysis = {
#       2         "Sample": "Sari15-04-33",
#       3         "T_C": 1200.0,  # Temperature in 'C
#    (...)     17         "Fe3FeT": 0.177,
#      18     }
#      20 my_analysis = pd.DataFrame(my_analysis, index=[0])
# ---> 22 result = vf.calc_gassing(my_analysis)
#      24 result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
#
# File ~\projects\VolFe\src\VolFe\batch_calculations.py:1818, in calc_gassing(setup, models, run, nr_step, nr_tol, dp_step, psat_tol, dwtg, i_nr_step, i_nr_tol, nr_step_eq, suppress_warnings)
#    1805 with warnings.catch_warnings():
#    1806     warnings.simplefilter(
#    1807         "ignore" if suppress_warnings else "default",
#    1808         category=RuntimeWarning,
#    1809     )
#    1810     (
#    1811         xg,
#    1812         conc,
#    1813         melt_and_gas,
#    1814         guesses,
#    1815         new_models,
#    1816         solve_species,
#    1817         mass_balance,
# -> 1818     ) = eq.mg_equilibrium(
#    1819         PT, melt_wf, bulk_wf, models, nr_step_eq, nr_tol, guesses
#    1820     )
#    1821 models = new_models
#    1822 # if xg["xg_O2"] == 1.0:
#    1823 #    print('tried resetting guesses')
#    1824 #    guesses = eq.initial_guesses(run,PT,melt_wf,setup,models,system)
#    (...)   1827 #    nr_step_eq, nr_tol,guesses)
#    1828 #    models = new_models
#
# File ~\projects\VolFe\src\VolFe\equilibrium_equations.py:830, in mg_equilibrium(PT, melt_wf, bulk_wf, models, nr_step, nr_tol, guesses)
#     821 elif (
#     822     models.loc["COH_species", "option"] == "yes_H2_CO_CH4_melt"
#     823     and models.loc["H2S_m", "option"] == True
#     824 ):
#     825     if models.loc["Hspeciation", "option"] in [
#     826         "none",
#     827         "none+regular",
#     828         "none+ideal",
#     829     ]:
# --> 830         A, B, C, D, models, solve_species = eq_SCHOFe_2(
#     831             PT,
#     832             bulk_wf,
#     833             melt_wf,
#     834             models,
#     835             nr_step,
#     836             nr_tol,
#     837             guesses,
#     838             solve_species,
#     839         )
#     840     elif models.loc["Hspeciation", "option"] == "linear":
#     841         A, B, C, D = eq_SCHOFe_3(
#     842             PT,
#     843             bulk_wf,
#    (...)    849             solve_species,
#     850         )
#
# File ~\projects\VolFe\src\VolFe\equilibrium_equations.py:7509, in eq_SCHOFe_2(PT, bulk_wf, melt_wf, models, nr_step, nr_tol, guesses, solve_species)
#    7507     guessy = guesses["xgCO"]
#    7508     guessz = guesses["xgS2"]
# -> 7509     xg_O2_, xg_CO_, xg_S2_ = jac_newton3(
#    7510         guessx, guessy, guessz, constants, f_SCHOFe, df_SCHOFe, nr_step, nr_tol
#    7511     )
#    7512 elif solve_species == "O2-H2-S2":
#    7513     guessy = guesses["xgH2"]
#
# File ~\projects\VolFe\src\VolFe\equilibrium_equations.py:2705, in jac_newton3(x0, y0, z0, constants, eqs, deriv, step, tol, maxiter)
#    2703 y0 = guessy
#    2704 z0 = guessz
# -> 2705 results1 = pd.DataFrame([[guessx, guessy, guessz, diff1, diff2, diff3, step]])
#    2706 results = pd.concat([results, results1], ignore_index=True)
#    2707 if n % 50 == 0:
#
# File c:\Users\erych\miniconda3\envs\volfe_dev\Lib\site-packages\pandas\core\frame.py:859, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     850         columns = ensure_index(columns)
#     851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)    857         dtype,
#     858     )
# --> 859     mgr = arrays_to_mgr(
#     860         arrays,
#     861         columns,
#     862         index,
#     863         dtype=dtype,
#     864         typ=manager,
#     865     )
#     866 else:
#     867     mgr = ndarray_to_mgr(
#     868         data,
#     869         index,
#    (...)    873         typ=manager,
#     874     )
#
# File c:\Users\erych\miniconda3\envs\volfe_dev\Lib\site-packages\pandas\core\internals\construction.py:152, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     149 axes = [columns, index]
#     151 if typ == "block":
# --> 152     return create_block_manager_from_column_arrays(
#     153         arrays, axes, consolidate=consolidate, refs=refs
#     154     )
#     155 elif typ == "array":
#     156     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\erych\miniconda3\envs\volfe_dev\Lib\site-packages\pandas\core\internals\managers.py:2139, in create_block_manager_from_column_arrays(arrays, axes, consolidate, refs)
#    2121 def create_block_manager_from_column_arrays(
#    2122     arrays: list[ArrayLike],
#    2123     axes: list[Index],
#    (...)   2135     # These last three are sufficient to allow us to safely pass
#    2136     #  verify_integrity=False below.
#    2138     try:
# -> 2139         blocks = _form_blocks(arrays, consolidate, refs)
#    2140         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    2141     except ValueError as e:
#
# File c:\Users\erych\miniconda3\envs\volfe_dev\Lib\site-packages\pandas\core\internals\managers.py:2212, in _form_blocks(arrays, consolidate, refs)
#    2209 if issubclass(dtype.type, (str, bytes)):
#    2210     dtype = np.dtype(object)
# -> 2212 values, placement = _stack_arrays(list(tup_block), dtype)
#    2213 if is_dtlike:
#    2214     values = ensure_wrapped_if_datetimelike(values)
#
# File c:\Users\erych\miniconda3\envs\volfe_dev\Lib\site-packages\pandas\core\internals\managers.py:2254, in _stack_arrays(tuples, dtype)
#    2252 stacked = np.empty(shape, dtype=dtype)
#    2253 for i, arr in enumerate(arrays):
# -> 2254     stacked[i] = arr
#    2256 return stacked, placement
#
# KeyboardInterrupt:

# %% [markdown]
# ### Simple test of calc_gassing function with sulfur saturation using example 2a

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.,  # wt%
        "CO2ppm": 100.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["sulfur_saturation", "True"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  88%|████████▊ | 299.0/338 [00:53<00:06,  5.61it/s]
# (337.8089065669246,
#  0.3903631833963219,
#  98.79891110755987,
#  0.00901325404278971,
#  1.0,
#  -0.483916101878636,
#  0.001833243745489121,
#  0.0007060269775851043)

# %% [markdown]
# ### Simple test of calc_gassing function with closed-system degassing and initial CO2 using example 2b

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.,  # wt%
        "CO2ppm": 100.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Fe3FeT": 0.177,
        "initial_CO2wtpc": 4.0,
    }  # initial CO2 content of the system in wt%

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["bulk_composition", "melt+vapor_initialCO2"], ["output csv", False]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  88%|████████▊ | 299.0/338 [00:41<00:05,  7.13it/s]
# (337.8089065669246,
#  0.3903631833963219,
#  98.79891110755987,
#  0.00901325404278971,
#  1.0,
#  -0.6901667944130256,
#  0.1940201296406095,
#  0.0048362983610370355)

# %% [markdown]
# ### Simple test of calc_gassing function with closed-system degassing and wtg using example 2b

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.,  # wt%
        "CO2ppm": 100.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Fe3FeT": 0.177,
        "wt_g": 3.0,
    }  # wt% vapor in equilibrium with the melt

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["bulk_composition", "melt+vapor_wtg"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  88%|████████▊ | 298.0/338 [00:59<00:08,  4.99it/s]
# (337.8089065669246,
#  0.3903631833963219,
#  98.79891110755987,
#  0.00901325404278971,
#  2.0,
#  -0.5457313637076062,
#  0.32690414099985654,
#  0.004065465875554149)

# %% [markdown]
# ### Simple test of calc_gassing function for open-system degassing using example 2c but with lower initial volatile content for speed

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 0.5,  # wt%
        "CO2ppm": 10.0,  # ppm
        "STppm": 100,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["gassing_style", "open"], ["output csv", False]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  96%|█████████▌| 45.0/47 [00:29<00:01,  1.55it/s]
# (46.30360083810482,
#  0.3828640585336194,
#  9.87748349636939,
#  0.0005557511517431813,
#  1.0,
#  0.3293057401161059,
#  0.0,
#  0.0)

# %% [markdown]
# ### Simple test of calc_gassing function for closed-system regassing using example 2d

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
        "initial_CO2wtpc": 3.0,  # initial CO2 content of the system in wt%
        "final_P": 4000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["gassing_direction", "regas"],
        ["bulk_composition", "melt+vapor_initialCO2"],
        ["output csv", False],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"],  result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
# 200.0it [00:04, 46.01it/s]
# (3869.8535236453786,
#  0.4734120855770545,
#  1472.4157582963953,
#  0.0006611502479165442,
#  4100.0,
#  0.47225372640648366,
#  1619.0205394465231,
#  0.0006938672105624531)

# %% [markdown]
# ### Simple test of calc_gassing function for open-system regassing using example 2d but to 4000 bar to save time

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
        "initial_CO2wtpc": 3.0,  # initial CO2 content of the system in wt%
        "final_P": 3900.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [
        ["gassing_direction", "regas"],
        ["gassing_style", "open"],
        ["output csv", False],
    ]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_gassing(my_analysis, models=my_models)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
# 100%|██████████| 31.0/31 [00:49<00:00,  1.60s/it]
# (3869.8535236453786,
#  0.4734120855770545,
#  1472.4157582963953,
#  0.0006611502479165442,
#  3901.0,
#  0.47296926980278187,
#  1494.1277819055208,
#  0.0006551773560027822)

# %% [markdown]
# ### Simple test of calc_gassing function for CHOAr system in basalt using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.0,  # wt%
        "CO2ppm": 100.0,  # ppm
        "Xppm": 1.0,  # ppm <<< treating this as Ar
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgX_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgX_mf"]
# Out:
#  95%|█████████▍| 299.0/315 [01:13<00:03,  4.06it/s]
# (314.0767584547407,
#  0.38975633889039596,
#  98.79749988350174,
#  0.039848999388785264,
#  1.0,
#  0.4882152820352932,
#  0.0020680645692377525,
#  5.060650006392194e-05)

# %% [markdown]
# ### Simple test of calc_gassing function for HSO system using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 1.0,  # wt%
        "CO2ppm": 0.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  98%|█████████▊| 119.0/122 [00:25<00:00,  4.60it/s]
# (121.0752719229832,
#  0.38479697596682794,
#  0.0,
#  0.02503594688216864,
#  1.0,
#  -0.4892544872641871,
#  0.0,
#  0.000726801036520788)

# %% [markdown]
# ### Simple test of calc_gassing function for CSO system using example 2e

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 0.0,  # wt%
        "CO2ppm": 100.0,  # ppm
        "STppm": 1000.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_gassing(my_analysis)

result.loc[0, "P_bar"], result.loc[0, "fO2_DFMQ"], result.loc[0, "CO2T_ppmw"], result.loc[0, "xgS2_mf"], result.loc[len(result) - 1, "P_bar"], result.loc[len(result) - 1, "fO2_DFMQ"], result.loc[len(result) - 1, "CO2T_ppmw"], result.loc[len(result) - 1, "xgS2_mf"]
# Out:
#  82%|████████▏ | 199.0/242 [00:53<00:11,  3.70it/s]
# (241.9094651596429,
#  0.3879069754214717,
#  98.78100907232741,
#  0.008259717364763537,
#  1.0,
#  -0.2796046953029556,
#  0.04928397455659001,
#  0.07090392314280476)

# %% [markdown]
# ## Test S2fO2 functions
#
# ### Simple test of calc_melt_S_oxybarometer function at Pvsat using example 3a

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
    }  # ppm

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_melt_S_oxybarometer(my_analysis)

result.loc[0, "P_bar_sulf"], result.loc[0, "fO2_DFMQ_sulf"], result.loc[0, "P_bar_anh"], result.loc[0, "fO2_DFMQ_anh"]
# Out:
# (3230.7350883331824, 0.7795276978567323, '', '')

# %% [markdown]
# ### Simple test of calc_melt_S_oxybarometer function at given P using example 3a

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
        "P_bar": 1000.0,  # bar
        "Fe3FeT": 0.1,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_melt_S_oxybarometer(my_analysis)

result.loc[0, "P_bar_sulf"], result.loc[0, "fO2_DFMQ_sulf"], result.loc[0, "P_bar_anh"], result.loc[0, "fO2_DFMQ_anh"]
# Out:
# (1000.0, 1.0825790760155174, 1000.0, '')

# %% [markdown]
# ### Simple test of calc_melt_S_oxybarometer function with sulfide composition using example 3a

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 1614.12,  # ppm
        "sulf_XFe": 0.8,
        "sulf_XCu": 0.15,
        "sulf_XNi": 0.05,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_melt_S_oxybarometer(my_analysis)

result.loc[0, "P_bar_sulf"], result.loc[0, "fO2_DFMQ_sulf"], result.loc[0, "P_bar_anh"], result.loc[0, "fO2_DFMQ_anh"]
# Out:
# (3269.7044309818853, 0.9650223648113823, '', '')

# %% [markdown]
# ### Simple test of calc_melt_S_oxybarometer function with user options

# %%
my_analysis = {
        "Sample": "Sari15-04-34",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 46.94,  # wt%
        "TiO2": 0.65,  # wt%
        "Al2O3": 16.0,  # wt%
        "FeOT": 8.92,  # wt%
        "MnO": 0.15,  # wt%
        "MgO": 7.3,  # wt%
        "CaO": 13.94,  # wt%
        "Na2O": 1.61,  # wt%
        "K2O": 0.26,  # wt%
        "P2O5": 0.07,  # wt%
        "H2O": 3.83,  # wt%
        "CO2ppm": 1109.0,  # ppm
        "STppm": 3000,  # ppm
        "sulf_XFe": 0.8,
        "sulf_XCu": 0.15,
        "sulf_XNi": 0.05,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["SCSS", "Fortin15_pss"], ["SCAS", "Chowdhury19_pss"], ["y_S2", "ideal"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_melt_S_oxybarometer(my_analysis, models=my_models)

result.loc[0, "P_bar_sulf"], result.loc[0, "fO2_DFMQ_sulf"], result.loc[0, "P_bar_anh"], result.loc[0, "fO2_DFMQ_anh"]
# Out:
# (3433.8254530901013, 1.00550953124662, '', '')

# %% [markdown]
# ## Test other functions
#
# ### Simple test of calc_fugacity_coefficients function using example 4a

# %%
my_analysis = {
        "Sample": "test",
        "T_C": 1200.0,  # Temperature in 'C
        "P_bar": 1000.0,
    }  # Pressure in bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_fugacity_coefficients(my_analysis)

result.loc[0, "yO2"], result.loc[0, "yS2"], result.loc[0, "yCO2"]
# Out:
# (1.209857826330598, 1.1913268980917349, 1.2657647433655634)

# %% [markdown]
# ### Simple test of calc_sol_consts function using example 4b

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "P_bar": 1000.0,  # Pressure in bar
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "H2O": 4.17,  # wt%
        "CO2ppm": 1487.0,  # ppm
        "STppm": 1343.5,  # ppm
        "Xppm": 0.0,  # ppm
        "Fe3FeT": 0.177,
    }

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_sol_consts(my_analysis)

result.loc[0, "ln[C_CH4]"], result.loc[0, "ln[C_S6+]"], result.loc[0, "ln[C_H2OT]"]
# Out:
# (-4.499332634382082, 29.85822594690088, -12.2869790594239)

# %% [markdown]
# ### Simple test of calc_pure_solubility using example 4c

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "Fe3FeT": 0.177,
        "initial_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

result = vf.calc_pure_solubility(my_analysis)

result.loc[1, "H2O_wtpc"], result.loc[500, "CO2_ppmw"]
# Out:
# (9.14715142977834, 2606.5792533661706)

# %% [markdown]
# ### Simple test of calc_pure_solubility with user defined options using example 4c

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "Fe3FeT": 0.195,
        "initial_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["water", "Rhyolite_HughesIP"], ["carbon dioxide", "Rhyolite_Blank93"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_pure_solubility(my_analysis, models=my_models)

result.loc[1, "H2O_wtpc"], result.loc[500, "CO2_ppmw"]
# Out:
# (9.958981268050458, 3025.990363824278)

# %% [markdown]
# ### Simple test of calc_isobar using example 4d

# %%
my_analysis = {
        "Sample": "Sari15-04-33",
        "T_C": 1200.0,  # Temperature in 'C
        "SiO2": 47.89,  # wt%
        "TiO2": 0.75,  # wt%
        "Al2O3": 16.74,  # wt%
        "FeOT": 9.43,  # wt%
        "MnO": 0.18,  # wt%
        "MgO": 5.92,  # wt%
        "CaO": 11.58,  # wt%
        "Na2O": 2.14,  # wt%
        "K2O": 0.63,  # wt%
        "P2O5": 0.17,  # wt%
        "Fe3FeT": 0.177,
        "initial_P": 5000.0,
    }  # bar

my_analysis = pd.DataFrame(my_analysis, index=[0])

my_models = [["COH_species", "H2O-CO2 only"]]

my_models = vf.make_df_and_add_model_defaults(my_models)

result = vf.calc_isobar(
        my_analysis, models=my_models, initial_P=1000.0, final_P=4000.0, step_P=1000.0
    )

result.loc[80, "P_bar"], result.loc[50, "H2O_wtpc"], result.loc[30, "CO2_ppm"]
# Out:
# (4000, 2.170719419802378, 869.9121719926527)
